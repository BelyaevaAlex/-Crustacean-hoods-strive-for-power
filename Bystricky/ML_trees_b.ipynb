# %%
from IPython.display import Image

# %% [markdown]
# ### 3.1. ML-trees in RAxML-NG and in IQ-TREE:

# %% [markdown]
# #### 1) 16S_alignment.fas:

# %%
! raxml-ng --msa 16S_alignment.fas --model HKY+G4 --prefix 16S_alignment_raxml --threads 2 --seed 222

# %%
! cat /content/16S_alignment_raxml.raxml.mlTrees # trees in newick format - the lengths of branches are specified
# Out:
# ((1MAR2_CWEA:0.002930,1VAL1_CWEA:0.002912):0.000001,(((1TRN2_CWEA:0.000001,((3KYC1_CWEA:0.000001,(1BYS2_CWEA:0.000001,((2KYC1_CWEA:0.000001,5KYC1_CWEA:0.000001):0.000001,((1KYC1_CWEA:0.000001,(1DRE2_CWEA:0.000001,((((5MAR2_EEQ:0.000001,(1DRE1_EEQ:0.003025,(((5DIN1_EEQ:0.002955,(1KYC2_EEQ:0.000001,((((1KOB2_EEQ:0.000001,1ZDE1_EEQ:0.000001):0.000001,1STA1_EEQ:0.000001):0.000001,(((1STA2_EEQ:0.000001,5KOB1_EEQ:0.000001):0.000001,(3KOB1_EEQ:0.000001,4KOB1_EEQ:0.000001):0.000001):0.000001,1MIL1_EEQ:0.000001):0.000001):0.000001,2KOB1_EEQ:0.000001):0.000001):0.000001):0.002963,1SOL1_EEQ:0.002996):0.000001,((((1PLU1_EEQ:0.000001,((1RUS1_EEQ:0.000001,1JAS1_EEQ:0.000001):0.000001,(5PRL1_EEQ:0.000001,(1TRN1_EEQ:0.000001,((1BZO2_EEQ:0.000001,6PRL1_EEQ:0.000001):0.000001,(2PRL1_EEQ:0.000001,1JAS2_EEQ:0.000001):0.000001):0.000001):0.000001):0.000001):0.000001):0.000001,1FRY1_EEQ:0.000001):0.000001,1PRL1_EEQ:0.000001):0.000001,(1UST1_EEQ:0.000001,1PLU2_EEQ:0.000001):0.000001):0.000001):0.000001):0.
# ...

# %%
! cat /content/16S_alignment_raxml.raxml.bestTree
# Out:
# ((((((4MAR2_CEA:0.000001,(6MAR2_CEA:0.000001,3MAR2_CEA:0.000001):0.000001):0.000001,2MAR2_CEA:0.000001):0.003085,(1VRA1_CEA:0.000001,1KOM-KOM_CEA:0.000001):0.000001):0.000001,1ZDE2_CEA:0.000001):0.000001,1HOV4_CEA:0.000001):0.000001,1HOV2_CEA:0.000001,((1DIN2_CEA:0.000001,((((((1HUT1_EEQ:0.000001,1KOB1_EEQ:0.000001):0.000001,1HOS1_EEQ:0.000001):0.000001,(1BLA-CAK_EEQ:0.000001,(1ZAS1_EEQ:0.000001,(5MAR2_EEQ:0.000001,(1MAR2_EEQ:0.000001,(((((1FRY1_EEQ:0.000001,1RUS1_EEQ:0.000001):0.000001,((((((1SOL1_EEQ:0.002960,(((1PRL1_EEQ:0.000001,1UST1_EEQ:0.000001):0.000001,(((1TRN1_EEQ:0.000001,5PRL1_EEQ:0.000001):0.000001,1JAS1_EEQ:0.000001):0.000001,1DRE1_EEQ:0.002986):0.000001):0.000001,2PRL1_EEQ:0.000001):0.000001):0.000001,1PLU2_EEQ:0.000001):0.000001,6PRL1_EEQ:0.000001):0.000001,1PLU1_EEQ:0.000001):0.000001,1JAS2_EEQ:0.000001):0.000001,1BZO2_EEQ:0.000001):0.000001):0.000001,(5DIN1_EEQ:0.002922,((((((((1KYC2_EEQ:0.000001,1STA1_EEQ:0.000001):0.000001,4KOB1_EEQ:0.000001):0.000001,(1MIL1_EEQ:0
# ...

# %%
! iqtree -m HKY+F+G4 -s 16S_alignment.fas --prefix 16S_alignment_iqtree

# %%
! cat 16S_alignment_iqtree.iqtree

# %%
! cat 16S_alignment_iqtree.treefile
# Out:
# (GpulexEF582877:0.6292377704,(2SK25_CWED:0.0052594308,((1REF235_CWED:0.0000010000,((2SK30_CWED:0.0000000000,4SEN1_CWED:0.0000000000):0.0000010000,1SEN2_CWED:0.0000010000):0.0000010000):0.0130667073,1SLI-BUD_CWED:0.0035174919):0.0076678351):0.0507437991,(((((((((1KOM-KOM_CEA:0.0000000000,1HOV1_CEA:0.0000000000):0.0000000000,1HOV2_CEA:0.0000000000):0.0000000000,1VRA1_CEA:0.0000000000):0.0000000000,1ZDE2_CEA:0.0000000000):0.0000000000,1HOV4_CEA:0.0000000000):0.0000010000,1DIN2_CEA:0.0000010000):0.0000010000,(((2MAR2_CEA:0.0000000000,6MAR2_CEA:0.0000000000):0.0000000000,4MAR2_CEA:0.0000000000):0.0000010000,3MAR2_CEA:0.0000010000):0.0031155714):0.0062878409,(((((3PRL1_CEA:0.0000000000,1ZAS2_CEA:0.0000000000):0.0000000000,1MIK2_CEA:0.0000000000):0.0000000000,1DIN1_CEA:0.0000000000):0.0000010000,4PRL1_CEA:0.0000010000):0.0000010000,(1SOL2_CEA:0.0000010000,1HUT2_CEA:0.0000010000):0.0031355929):0.0000026471):0.0526950123,((((((((((1BLA-CAK_EEQ:0.0000000000,1HOS1_EEQ:0.0000000000):0.0000000000
# ...

# %% [markdown]
# Check:

# %%
! cat 16S_ML_tree.nwk
# Out:
# (((((((((((((((((((1KYC2_EEQ:0.0,1MIL1_EEQ:0.0):0.0,1ZDE1_EEQ:0.0):0.0,1STA2_EEQ:0.0):0.0,1KOB2_EEQ:0.0):0.0,5KOB1_EEQ:0.0):0.0,4KOB1_EEQ:0.0):0.0,3KOB1_EEQ:0.0):0.0,5DIN1_EEQ:0.0029879999999999907):0.0,2KOB1_EEQ:0.0):0.0,1STA1_EEQ:0.0):0.002990999999999966,((1SOL1_EEQ:0.0030160000000000187,1DRE1_EEQ:0.003033000000000008):0.0,1UST1_EEQ:0.0):0.0):0.0,(((((((((((1FRY1_EEQ:0.0,1JAS2_EEQ:0.0):0.0,1BZO2_EEQ:0.0):0.0,1RUS1_EEQ:0.0):0.0,1PLU2_EEQ:0.0):0.0,1PLU1_EEQ:0.0):0.0,1JAS1_EEQ:0.0):0.0,6PRL1_EEQ:0.0):0.0,5PRL1_EEQ:0.0):0.0,2PRL1_EEQ:0.0):0.0,1PRL1_EEQ:0.0):0.0,1TRN1_EEQ:0.0):0.0):0.0030000000000000027,(1HOS1_EEQ:0.0,1ZUB1_EEQ:0.0029899999999999927):0.0):0.0,(((((5MAR1_EEQ:0.0,1HUT1_EEQ:0.0):0.0,1MAR1_EEQ:0.0):0.0,6KOB1_EEQ:0.0):0.0,1KOB1_EEQ:0.0):0.0,1BLA-CAK_EEQ:0.0):0.0):0.0,1ZAS1_EEQ:0.0):0.12645799999999996,(((((((((((1BYS2_CWEA:0.0,3CER2_CWEA:0.0):0.0,6KYC1_CWEA:0.0):0.0,5KYC1_CWEA:0.0):0.0,4KYC1_CWEA:0.0):0.0,3KYC1_CWEA:0.0):0.0,2KYC1_CWEA:0.0):0.0,((1UST2_CWEA:0.0,2UST1_CWEA:0
# ...

# %% [markdown]
# #### 2) 28S_alignment.fas:

# %%
! raxml-ng --msa 28S_alignment.fas --model HKY+I --prefix 28S_alignment_raxml --threads 2 --seed 222

# %%
! cat /content/28S_alignment_raxml.raxml.mlTrees
# Out:
# (((HBRG3_CEA:0.000001,PAPSKG1_CEA:0.000001):0.001712,(((4MIK1_CEA:0.000001,1HOV4_CEA:0.000001):0.000001,1DIN2_CEA:0.000001):0.000001,(3KYC2_CEA:0.000001,5ZUB2_CEA:0.000001):0.000001):0.000001):0.000001,((((((((5HOV3_CEA:0.000001,3PRL1_CEA:0.000001):0.000001,(1HUT2_CEA:0.000001,1SK21_CEA:0.000001):0.000001):0.000001,(3HOV2_CEA:0.000001,1MIK2_CEA:0.000001):0.000001):0.000001,(2MAR1_CEA:0.000001,2CER2_CEA:0.000001):0.000001):0.000001,1VRA1_CEA:0.000001):0.000001,1SOL2_CEA:0.000001):0.000001,(((((2VRA2_EEQ:0.000001,((((1HOS1_EEQ:0.000001,3HOV4_EEQ:0.000001):0.000001,((4JUH1_EEQ:0.000001,1MAR1_EEQ:0.000001):0.000001,(1PRL1_EEQ:0.000001,(4TRN2_EEQ:0.000001,(((((1KYC2_EEQ:0.000001,(((NDVG2_EEQ:0.000001,5CER1_EEQ:0.000001):0.000001,HBRG2_EEQ:0.000001):0.000001,(PAPCZG1_EEQ:0.000001,DURCZG1_EEQ:0.000001):0.000001):0.000001):0.000001,(1ZDRVOD_EEQ:0.000001,3JUH1_EEQ:0.000001):0.000001):0.000001,(1DRE1_EEQ:0.000001,4UST1_EEQ:0.000001):0.000001):0.000001,1UST1_EEQ:0.000001):0.000001,2HOV2_EEQ:0.0
# ...

# %%
! cat /content/28S_alignment_raxml.raxml.bestTree
# Out:
# ((1PRL1_EEQ:0.000001,(5DIN1_EEQ:0.000001,(PAPCZG1_EEQ:0.000001,(HBRG2_EEQ:0.000001,(NDVG2_EEQ:0.000001,(1UST1_EEQ:0.000001,(1CZK1_EEQ:0.000001,(2VRA2_EEQ:0.000001,(((4SEN1_CWED:0.000001,1REF235_CWED:0.000001):0.000001,1SEN2_CWED:0.000001):0.000841,((1HUN16_CWED:0.000001,2SK25_CWED:0.000001):0.000001,(((((((((((((((((3CER2_CWEA:0.000001,2MIK1_CWEA:0.000001):0.000845,(1CER1_CWEA:0.000001,2PRG_CWEA:0.000001):0.000001):0.000001,4KYC2_CWEA:0.000001):0.000001,2DIN2_CWEA:0.000001):0.000001,2LUZ1_CWEA:0.000001):0.000001,((((2VRA1_CWEA:0.000001,3UST1_CWEA:0.000001):0.000001,1HOV3_CWEA:0.000001):0.000001,POZSKG1_CWEA:0.000001):0.000001,2UST1_CWEA:0.000001):0.000001):0.000001,1LUZ2_CWEA:0.000001):0.000001,1MARSEN_CWEA:0.000001):0.000001,5LUZ2_CWEA:0.000001):0.000001,2ZUB2_CWEA:0.000001):0.000001,(1KRE-PRA_CWEA:0.000845,3SEN1_CWEA:0.000001):0.000001):0.000001,1MRAOLS_CWEA:0.000001):0.000001,1CER2_CWEA:0.000001):0.000001,1LET_CWEA:0.000001):0.000001,1SEN1_CWEA:0.000001):0.001549,GpulexSLOCHN022:0
# ...

# %%
! iqtree -m HKY+F+I  -s 28S_alignment.fas --prefix 28S_alignment_iqtree

# %%
! cat 28S_alignment_iqtree.iqtree

# %%
! cat 28S_alignment_iqtree.treefile
# Out:
# (1HUN16_CWED:0.0000010000,((((1REF235_CWED:0.0000000000,4SEN1_CWED:0.0000000000):0.0000010000,1SEN2_CWED:0.0000010000):0.0008412088,(((((((((((((((((((((HBRG2_EEQ:0.0000000000,4TRN2_EEQ:0.0000000000):0.0000000000,1ZDRVOD_EEQ:0.0000000000):0.0000000000,1MAR1_EEQ:0.0000000000):0.0000000000,4UST1_EEQ:0.0000000000):0.0000000000,5DIN1_EEQ:0.0000000000):0.0000000000,3HOV4_EEQ:0.0000000000):0.0000000000,1UST1_EEQ:0.0000000000):0.0000000000,2VRA2_EEQ:0.0000000000):0.0000000000,3JUH1_EEQ:0.0000000000):0.0000000000,1STA1_EEQ:0.0000000000):0.0000000000,1PRL1_EEQ:0.0000000000):0.0000000000,PAPCZG1_EEQ:0.0000000000):0.0000000000,1CZK1_EEQ:0.0000000000):0.0000000000,1KYC2_EEQ:0.0000000000):0.0000000000,2HOV2_EEQ:0.0000000000):0.0000000000,1DRE1_EEQ:0.0000000000):0.0000000000,4JUH1_EEQ:0.0000000000):0.0000000000,NDVG2_EEQ:0.0000000000):0.0000000000,1HOS1_EEQ:0.0000000000):0.0000010000,DURCZG1_EEQ:0.0000010000):0.0000010000,(3MAR2_EEQ:0.0000010000,5CER1_EEQ:0.0000010000):0.0000010000):0.0034724616):
# ...

# %% [markdown]
# Check:

# %%
! cat 28S_ML_tree.nwk
# Out:
# (((((((((((((((((((4UST1_EEQ:0.0,5DIN1_EEQ:0.0):0.0,4TRN2_EEQ:0.0):0.0,4JUH1_EEQ:0.0):0.0,3JUH1_EEQ:0.0):0.0,2HOV2_EEQ:0.0):0.0,1UST1_EEQ:0.0):0.0,1STA1_EEQ:0.0):0.0,1PRL1_EEQ:0.0):0.0,1MAR1_EEQ:0.0):0.0,1KYC2_EEQ:0.0):0.0,1HOS1_EEQ:0.0):0.0,1DRE1_EEQ:0.0):0.0,5CER1_EEQ:0.0):0.0,((((((((2VRA2_EEQ:0.0,3HOV4_EEQ:0.0):0.0,3MAR2_EEQ:0.0):0.0,NDVG2_EEQ:0.0):0.0,1ZDRVOD_EEQ:0.0):0.0,1CZK1_EEQ:0.0):0.0,PAPCZG1_EEQ:0.0):0.0,DURCZG1_EEQ:0.0):0.0,HBRG2_EEQ:0.0):0.0):0.003383000000000004,((1SEN2_CWED:0.0,4SEN1_CWED:0.0):0.0,1REF235_CWED:0.0):8.420000000000025E-4):8.449999999999985E-4,(1HUN16_CWED:0.0,2SK25_CWED:0.0):0.0):8.489999999999991E-4,((((((((((((((((((4VRA1_CEA:0.0,5HOV3_CEA:0.0):0.0,4MIK1_CEA:0.0):0.0,3PRL1_CEA:0.0):0.0,3KYC2_CEA:0.0):0.0,3HOV2_CEA:0.0):0.0,3DIN2_CEA:0.0):0.0,2MAR1_CEA:0.0):0.0,1VRA1_CEA:0.0):0.0,1SOL2_CEA:0.0):0.0,1HUT2_CEA:0.0):0.0,1HOV4_CEA:0.0):0.0,1DIN2_CEA:0.0):0.0,1DIN1_CEA:0.0):0.0,1MIK2_CEA:0.0):0.0,2CER2_CEA:0.0):0.0,1SK21_CEA:0.0):0.0,1SK24_CEA:0.0):0.0,((HB
# ...

# %% [markdown]
# #### 3) EF1a_alignment_phased.fas:

# %%
! raxml-ng --msa EF1a_alignment_phased.fas --model K80+I+G4 --prefix EF1a_alignment_phased_raxml --threads 2 --seed 222

# %%
! cat /content/EF1a_alignment_phased_raxml.raxml.mlTrees
# Out:
# (4SEN1_CWEDa:0.005990,((((((1DIN2_CEAa:0.001861,1HUT2_CEAb:0.001878):0.001908,(HBRG3_CEAa:0.001868,1HOV4_CEAb:0.003764):0.000001):0.000001,PAPSKG1_CEAa:0.000001):0.000001,(1MIK2_CEAb:0.001879,1SOL2_CEAa:0.000001):0.001884):0.002022,(5LUZ2_CWEAb:0.001923,((2UST1_CWEAa:0.000001,2PRG_CWEAa:0.000001):0.000001,((((1KRE-PRA_CWEAa:0.000001,1LET_CWEAa:0.000001):0.000001,3CER2_CWEAb:0.001868):0.000001,(1MAR-SEN_CWEAa:0.000001,(((1KRE-PRA_CWEAb:0.005995,((((3CER2_CWEAa:0.001869,1MRA-OLS_CWEAb:0.001889):0.000001,((POZSKG1_CWEAb:0.001890,2PRG_CWEAb:0.007819):0.001921,(5LUZ2_CWEAa:0.000001,2UST1_CWEAb:0.000001):0.001882):0.001858):0.001878,1LET_CWEAb:0.001878):0.000001,1MAR-SEN_CWEAb:0.005685):0.005750):0.004482,((((1DIN2_CEAb:0.003857,(((1SK24_CEAb:0.001881,1SK21_CEAb:0.000001):0.018705,PAPSKG1_CEAb:0.004166):0.003538,(((HBRG3_CEAb:0.000001,(1MIK2_CEAa:0.000001,1HUT2_CEAa:0.000001):0.000001):0.000001,1HOV4_CEAa:0.000001):0.000001,1SOL2_CEAb:0.001870):0.000001):0.003855):0.009917,1SK24_CEAa:0.000
# ...

# %%
! cat /content/EF1a_alignment_phased_raxml.raxml.bestTree
# Out:
# (((1MAR-SEN_CWEAa:0.000001,(((1LET_CWEAa:0.000001,1KRE-PRA_CWEAa:0.000001):0.000001,3CER2_CWEAb:0.001870):0.000001,((((((((1MIK2_CEAb:0.001880,1SOL2_CEAa:0.000001):0.001886,(HBRG3_CEAa:0.001870,1HOV4_CEAb:0.003768):0.000001):0.000001,PAPSKG1_CEAa:0.000001):0.000001,(1HUT2_CEAb:0.001881,1DIN2_CEAa:0.001862):0.001910):0.002026,(((1UST1_EEQa:0.000001,((4JUH1_EEQa:0.000001,(1ZDR-VOD_EEQa:0.000001,1HOS1_EEQa:0.000001):0.000001):0.000001,(1KYC2_EEQa:0.000001,5DIN1_EEQa:0.000001):0.000001):0.000001):0.000001,((((DURCZG1_EEQa:0.011736,HBRG2_EEQa:0.000001):0.003768,(NDVG2_EEQb:0.000001,1STA1_EEQa:0.000001):0.000001):0.001954,1CZK1_EEQa:0.009941):0.001812,PAPCZG1_EEQa:0.000001):0.001870):0.001817,(((1HUN16_CWEDb:0.000001,1SEN2_CWEDb:0.005731):0.001907,(1REF_235_CWEDb:0.000001,2SK25_CWEDb:0.000001):0.001873):0.003742,4SEN1_CWEDa:0.006002):0.008238):0.001917):0.003850,5LUZ2_CWEAb:0.001926):0.003801,(2PRG_CWEAa:0.000001,2UST1_CWEAa:0.000001):0.000001):0.001899,(POZSKG1_CWEAa:0.000001,1MRA-OLS_CWE
# ...

# %%
! iqtree -m K2P+R2  -s EF1a_alignment_phased.fas  --prefix EF1a_alignment_phase_iqtree

# %%
! cat EF1a_alignment_phase_iqtree.iqtree

# %%
! cat EF1a_alignment_phase_iqtree.treefile
# Out:
# (1REF_235_CWEDa:0.0000010256,(((((((((((((((1REF_235_CWEDb:0.0000010256,2SK25_CWEDb:0.0000010256):0.0018736711,(1HUN16_CWEDb:0.0000010256,1SEN2_CWEDb:0.0056774615):0.0018793310):0.0037126098,4SEN1_CWEDa:0.0059534744):0.0082479076,(((1CZK1_EEQa:0.0098455203,((1STA1_EEQa:0.0000010256,NDVG2_EEQb:0.0000010256):0.0000010256,(DURCZG1_EEQa:0.0116384231,HBRG2_EEQa:0.0000010256):0.0037411730):0.0019495697):0.0017867329,PAPCZG1_EEQa:0.0000010256):0.0018557858,(((((1HOS1_EEQa:0.0000000000,4JUH1_EEQa:0.0000000000):0.0000000000,1UST1_EEQa:0.0000000000):0.0000000000,5DIN1_EEQa:0.0000000000):0.0000000000,1ZDR-VOD_EEQa:0.0000000000):0.0000010256,1KYC2_EEQa:0.0000010256):0.0000010256):0.0018378339):0.0018611795,(((1DIN2_CEAa:0.0018417925,1HUT2_CEAb:0.0018709499):0.0018914954,((1HOV4_CEAb:0.0037394405,(1MIK2_CEAb:0.0018624852,1SOL2_CEAa:0.0000010256):0.0018754645):0.0000010256,PAPSKG1_CEAa:0.0000010256):0.0000010256):0.0000010256,HBRG3_CEAa:0.0018553431):0.0020182345):0.0038387449,5LUZ2_CWEAb:0.001896
# ...

# %% [markdown]
# Check:

# %%
! cat EF1a_ML_tree.nwk
# Out:
# (((((((((((((1HUT2_CEAa:0.0,1MIK2_CEAa:0.0):0.0,1HOV4_CEAa:0.0):0.0,((HBRG3_CEAb:0.0,PAPSKG1_CEAb:0.007979):0.0,1SOL2_CEAb:0.0019300000000000012):0.0):0.003945999999999998,1DIN2_CEAb:0.003948):0.010003999999999999,1SK24_CEAa:0.0):0.003951,1SK21_CEAa:0.0019260000000000006):0.003941,((((1HUN16_CWEDa:0.0,4SEN1_CWEDb:0.0019419999999999993):0.0019419999999999993,1SEN2_CWEDa:0.0):0.0,2SK25_CWEDa:0.012035000000000004):0.0,1REF_235_CWEDa:0.0):0.006010999999999999):0.008326999999999998,((((((1UST1_EEQb:0.0,5DIN1_EEQb:0.0):0.0019319999999999997,1ZDR-VOD_EEQb:0.007992000000000003):0.0,PAPCZG1_EEQb:0.0):0.0,(DURCZG1_EEQb:0.0,HBRG2_EEQb:0.0):0.0058540000000000016):0.0,(((1STA1_EEQb:0.0,4JUH1_EEQb:0.0):0.0,1KYC2_EEQb:0.0):0.0,1HOS1_EEQb:0.0):0.0):0.0019449999999999988,(1CZK1_EEQb:0.005843000000000001,NDVG2_EEQa:0.0039030000000000002):0.0):0.007965):0.008251000000000001,((1SK21_CEAb:0.0,1SK24_CEAb:0.0019419999999999993):0.018998999999999995,DURCZG1_EEQa:0.010553999999999994):0.0015560000000000018):
# ...

# %% [markdown]
# ### 3.2. Visualization of ML-trees:

# %% [markdown]
# By the appearance of the tree in the format, it is already clear that in the original article we got a slightly different result .nwk. Let's make sure of this by drawing these trees.

# %%
import requests
import pylab
from io import StringIO
from Bio import Phylo
import random
from ete3 import Tree, TreeStyle, NodeStyle
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1) 16S_alignment.fas:

# %%
tree_16s_iq = Phylo.read('16S_alignment_iqtree.treefile', "newick")

# %%
mpl.rc('font', size=3)
Phylo.draw(tree_16s_iq, do_show=False)

# %%
tree_16s_r = Phylo.read('16S_alignment_raxml.raxml.bestTree', "newick")

# %%
mpl.rc('font', size=3)
Phylo.draw(tree_16s_r, do_show=False)

# %%
tree_16s_example = Phylo.read('16S_ML_tree.nwk', "newick")

# %%
mpl.rc('font', size=3)
Phylo.draw(tree_16s_example, do_show=False)

# %% [markdown]
# #### 2) 28S_alignment.fas:

# %%
tree_28s_iq = Phylo.read('28S_alignment_iqtree.treefile', "newick")

# %%
mpl.rc('font', size=3)
Phylo.draw(tree_28s_iq, do_show=False)

# %%
tree_28s_r = Phylo.read('28S_alignment_raxml.raxml.bestTree', "newick")

# %%
mpl.rc('font', size=3)
Phylo.draw(tree_28s_r, do_show=False)

# %%
tree_28s_example = Phylo.read('28S_ML_tree.nwk', "newick")

# %%
mpl.rc('font', size=3)
Phylo.draw(tree_28s_example, do_show=False)

# %% [markdown]
# #### 3) EF1a_alignment_phased.fas:

# %%
tree_EF1a_iq = Phylo.read('EF1a_alignment_phase_iqtree.treefile', "newick")

# %%
mpl.rc('font', size=3)
Phylo.draw(tree_EF1a_iq, do_show=False)

# %%
tree_EF1a_r = Phylo.read('EF1a_alignment_phased_raxml.raxml.bestTree', "newick")

# %%
mpl.rc('font', size=3)
Phylo.draw(tree_EF1a_r, do_show=False)

# %%
tree_EF1a_example = Phylo.read('EF1a_ML_tree.nwk', "newick")

# %%
mpl.rc('font', size=3)
Phylo.draw(tree_EF1a_example, do_show=False)

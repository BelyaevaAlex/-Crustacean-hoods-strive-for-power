# %% [markdown]
# ### 0. Preparing the environment:

# %%
# %%bash
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.5.4-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
# Out:
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-hf484d3e_0 ...
# installing: openssl-1.0.2o-h20670df_0 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: xz-5.2.4-h14c3975_4 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-ha838bed_2 ...
# installing: libedit-3.1.20170329-h6b74fdf_2 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: sqlite-3.23.1-he433501_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: certifi-2018.4.16-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: idna-2.6-py36h82fb2a8_1 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pysocks-1.6.8-py36_0 ...
# ...

# %%
# %%bash
# conda install --channel defaults conda python=3.6 --yes
# conda update --channel defaults --all --yes
# Out:
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#     - python=3.6
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     sqlite-3.38.5              |       hc218d9a_0         1.5 MB
#     libgcc-ng-9.1.0            |       hdf63c60_0         8.1 MB
#     pycosat-0.6.3              |   py36h27cfd23_0         107 KB
#     setuptools-58.0.4          |   py36h06a4308_0         979 KB
#     yaml-0.2.5                 |       h7b6447c_0          87 KB
#     pip-21.2.2                 |   py36h06a4308_0         2.1 MB
#     python-3.6.13              |       h12debd9_1        32.5 MB
#     tk-8.6.12                  |       h1ccaba5_0         3.3 MB
#     libffi-3.3                 |       he6710b0_2          54 KB
#     ld_impl_linux-64-2.38      |       h1181459_1         732 KB
# ...

# %%
# !conda install -c bioconda trimal
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 23.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - trimal
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     trimal-1.4.1               |       h9f5acd7_6         183 KB  bioconda
#     ------------------------------------------------------------
#                                            Total:         183 KB
#
# The following NEW packages will be INSTALLED:
#
#   trimal             bioconda/linux-64::trimal-1.4.1-h9f5acd7_6
#
#
# Proceed ([y]/n)? y
#
#
# ...
# trimal-1.4.1         | 183 KB    | : 100% 1.0/1 [00:00<00:00,  3.26it/s]
# done
# done
# done

# %%
# !conda install -c bioconda raxml-ng
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 23.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - raxml-ng
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     gmp-6.2.1                  |       h295c915_3         544 KB
#     libgfortran-ng-7.5.0       |      ha8ba4b0_17          22 KB
#     libgfortran4-7.5.0         |      ha8ba4b0_17         995 KB
#     mpi-1.0                    |          openmpi           7 KB
#     openmpi-4.0.2              |       hb1b8bf9_1         3.5 MB
# ...

# %%
! conda install -c bioconda modeltest-ng
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 23.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - modeltest-ng
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     modeltest-ng-0.1.6         |       h78e549b_0         2.5 MB  bioconda
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   modeltest-ng       bioconda/linux-64::modeltest-ng-0.1.6-h78e549b_0
#
#
# ...

# %%
! conda install -c bioconda modeltest-ng
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 23.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.

# %%
! conda install -c bioconda iqtree
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 23.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - iqtree
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     iqtree-2.0.3               |       h176a8bc_1         3.0 MB  bioconda
#     ------------------------------------------------------------
#                                            Total:         3.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   iqtree             bioconda/linux-64::iqtree-2.0.3-h176a8bc_1
#
#
# Proceed ([y]/n)? y
#
#
# ...
# iqtree-2.0.3         | 3.0 MB    | : 100% 1.0/1 [00:01<00:00,  1.14s/it]
# done
# done
# done

# %%
! conda install -c bioconda beast2
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# failed with initial frozen solve. Retrying with flexible solve.
# -
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
#
# UnsatisfiableError: The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versions
#
# Package libgcc-ng conflicts for:
# python=3.6 -> ncurses[version='>=6.2,<7.0a0'] -> libgcc-ng[version='>=11.2.0']
# beast2 -> beagle-lib -> libgcc-ng[version='>=10.3.0|>=12|>=9.3.0|>=7.5.0|>=7.3.0|>=4.9|>=11.2.0|>=7.2.0']
# python=3.6 -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']The following specifications were found to be incompatible with your system:
#
#   - feature:/linux-64::__glibc==2.31=0
# ...

# %% [markdown]
# ## 4. We cut out the bad areas from the alignment using trimAl:

# %%
! trimal -in sequences_Moskalenko_s_16_muscle.fa -out sequences_Moskalenko_s_16_muscle.trim.fas -automated1 # лучше сразу указывать метод 
# -automated1 - так как далее собираемся строить дерево методом максимального правдоподобия

# %%
! trimal -in sequences_Moskalenko_s_18_muscle.fa -out sequences_Moskalenko_s_18_muscle.trim.fas -automated1

# %%
! trimal -in sequences_Moskalenko_s_28_muscle.fa -out sequences_Moskalenko_s_28_muscle.trim.fas -automated1

# %%
! trimal -in sequences_Moskalenko_coi_muscle.fa -out sequences_Moskalenko_coi_muscle.trim.fas -automated1

# %%
! trimal -in sequences_Moskalenko_eF1a_muscle.fa -out sequences_Moskalenko_eF1a_muscle.trim.fas -automated1

# %%
! trimal -in sequences_Moskalenko_h3_muscle.fa -out sequences_Moskalenko_h3_muscle.trim.fas -automated1

# %%
! trimal -in sequences_Moskalenko_all_muscle.fas -out sequences_Moskalenko_all_muscle.trim.fas -automated1

# %%
! trimal -in sequences_Moskalenko_gr1_muscle.fas -out sequences_Moskalenko_gr1_muscle.trim.fas -automated1

# %%
! trimal -in sequences_Moskalenko_gr2_muscle.fas -out sequences_Moskalenko_gr2_muscle.trim.fas -automated1

# %% [markdown]
# ## 5. Selecting an evolution model in ModelTest (ModelTest-NG):

# %%
! modeltest-ng -i sequences_Moskalenko_s_16_muscle.trim.fas -o sequences_Moskalenko_s_16_muscle_trim_modeltest
# Out:
#                              _      _ _            _      _   _  _____
#                             | |    | | |          | |    | \ | |/ ____|
#          _ __ ___   ___   __| | ___| | |_ ___  ___| |_   |  \| | |  __
#         | '_ ` _ \ / _ \ / _` |/ _ \ | __/ _ \/ __| __|  | . ` | | |_ |
#         | | | | | | (_) | (_| |  __/ | ||  __/\__ \ |_   | |\  | |__| |
#         |_| |_| |_|\___/ \__,_|\___|_|\__\___||___/\__|  |_| \_|\_____|
# --------------------------------------------------------------------------------
# modeltest x.y.z
# Copyright (C) 2017 Diego Darriba, David Posada, Alexandros Stamatakis
# License GPLv3+: GNU GPL version 3 or later <http://gnu.org/licenses/gpl.html>.
# This is free software: you are free to change and redistribute it.
# There is NO WARRANTY, to the extent permitted by law.
#
# Written by Diego Darriba.
# --------------------------------------------------------------------------------
#
# Physical cores: 1
# Logical cores:  2
# ...

# %%
! modeltest-ng -i sequences_Moskalenko_s_18_muscle.trim.fas -o sequences_Moskalenko_s_18_muscle_trim_modeltest
# Out:
#                              _      _ _            _      _   _  _____
#                             | |    | | |          | |    | \ | |/ ____|
#          _ __ ___   ___   __| | ___| | |_ ___  ___| |_   |  \| | |  __
#         | '_ ` _ \ / _ \ / _` |/ _ \ | __/ _ \/ __| __|  | . ` | | |_ |
#         | | | | | | (_) | (_| |  __/ | ||  __/\__ \ |_   | |\  | |__| |
#         |_| |_| |_|\___/ \__,_|\___|_|\__\___||___/\__|  |_| \_|\_____|
# --------------------------------------------------------------------------------
# modeltest x.y.z
# Copyright (C) 2017 Diego Darriba, David Posada, Alexandros Stamatakis
# License GPLv3+: GNU GPL version 3 or later <http://gnu.org/licenses/gpl.html>.
# This is free software: you are free to change and redistribute it.
# There is NO WARRANTY, to the extent permitted by law.
#
# Written by Diego Darriba.
# --------------------------------------------------------------------------------
#
# Physical cores: 1
# Logical cores:  2
# ...

# %%
! modeltest-ng -i sequences_Moskalenko_s_28_muscle.trim.fas -o sequences_Moskalenko_s_28_muscle_trim_modeltest
# Out:
#                              _      _ _            _      _   _  _____
#                             | |    | | |          | |    | \ | |/ ____|
#          _ __ ___   ___   __| | ___| | |_ ___  ___| |_   |  \| | |  __
#         | '_ ` _ \ / _ \ / _` |/ _ \ | __/ _ \/ __| __|  | . ` | | |_ |
#         | | | | | | (_) | (_| |  __/ | ||  __/\__ \ |_   | |\  | |__| |
#         |_| |_| |_|\___/ \__,_|\___|_|\__\___||___/\__|  |_| \_|\_____|
# --------------------------------------------------------------------------------
# modeltest x.y.z
# Copyright (C) 2017 Diego Darriba, David Posada, Alexandros Stamatakis
# License GPLv3+: GNU GPL version 3 or later <http://gnu.org/licenses/gpl.html>.
# This is free software: you are free to change and redistribute it.
# There is NO WARRANTY, to the extent permitted by law.
#
# Written by Diego Darriba.
# --------------------------------------------------------------------------------
#
# Physical cores: 1
# Logical cores:  2
# ...

# %%
! modeltest-ng -i sequences_Moskalenko_coi_muscle.trim.fas -o sequences_Moskalenko_coi_muscle_trim_modeltest
# Out:
#                              _      _ _            _      _   _  _____
#                             | |    | | |          | |    | \ | |/ ____|
#          _ __ ___   ___   __| | ___| | |_ ___  ___| |_   |  \| | |  __
#         | '_ ` _ \ / _ \ / _` |/ _ \ | __/ _ \/ __| __|  | . ` | | |_ |
#         | | | | | | (_) | (_| |  __/ | ||  __/\__ \ |_   | |\  | |__| |
#         |_| |_| |_|\___/ \__,_|\___|_|\__\___||___/\__|  |_| \_|\_____|
# --------------------------------------------------------------------------------
# modeltest x.y.z
# Copyright (C) 2017 Diego Darriba, David Posada, Alexandros Stamatakis
# License GPLv3+: GNU GPL version 3 or later <http://gnu.org/licenses/gpl.html>.
# This is free software: you are free to change and redistribute it.
# There is NO WARRANTY, to the extent permitted by law.
#
# Written by Diego Darriba.
# --------------------------------------------------------------------------------
#
# Physical cores: 1
# Logical cores:  2
# ...

# %%
! modeltest-ng -i sequences_Moskalenko_eF1a_muscle.trim.fas -o sequences_Moskalenko_eF1a_muscle_trim_modeltest
# Out:
#                              _      _ _            _      _   _  _____
#                             | |    | | |          | |    | \ | |/ ____|
#          _ __ ___   ___   __| | ___| | |_ ___  ___| |_   |  \| | |  __
#         | '_ ` _ \ / _ \ / _` |/ _ \ | __/ _ \/ __| __|  | . ` | | |_ |
#         | | | | | | (_) | (_| |  __/ | ||  __/\__ \ |_   | |\  | |__| |
#         |_| |_| |_|\___/ \__,_|\___|_|\__\___||___/\__|  |_| \_|\_____|
# --------------------------------------------------------------------------------
# modeltest x.y.z
# Copyright (C) 2017 Diego Darriba, David Posada, Alexandros Stamatakis
# License GPLv3+: GNU GPL version 3 or later <http://gnu.org/licenses/gpl.html>.
# This is free software: you are free to change and redistribute it.
# There is NO WARRANTY, to the extent permitted by law.
#
# Written by Diego Darriba.
# --------------------------------------------------------------------------------
#
# Physical cores: 1
# Logical cores:  2
# ...

# %%
! modeltest-ng -i sequences_Moskalenko_h3_muscle.trim.fas -o sequences_Moskalenko_h3_muscle_trim_modeltest
# Out:
#                              _      _ _            _      _   _  _____
#                             | |    | | |          | |    | \ | |/ ____|
#          _ __ ___   ___   __| | ___| | |_ ___  ___| |_   |  \| | |  __
#         | '_ ` _ \ / _ \ / _` |/ _ \ | __/ _ \/ __| __|  | . ` | | |_ |
#         | | | | | | (_) | (_| |  __/ | ||  __/\__ \ |_   | |\  | |__| |
#         |_| |_| |_|\___/ \__,_|\___|_|\__\___||___/\__|  |_| \_|\_____|
# --------------------------------------------------------------------------------
# modeltest x.y.z
# Copyright (C) 2017 Diego Darriba, David Posada, Alexandros Stamatakis
# License GPLv3+: GNU GPL version 3 or later <http://gnu.org/licenses/gpl.html>.
# This is free software: you are free to change and redistribute it.
# There is NO WARRANTY, to the extent permitted by law.
#
# Written by Diego Darriba.
# --------------------------------------------------------------------------------
#
# Physical cores: 1
# Logical cores:  2
# ...

# %%
! modeltest-ng -i sequences_Moskalenko_all_muscle.trim.fas -o sequences_Moskalenko_all_muscle_trim_modeltest
# Out:
#                              _      _ _            _      _   _  _____
#                             | |    | | |          | |    | \ | |/ ____|
#          _ __ ___   ___   __| | ___| | |_ ___  ___| |_   |  \| | |  __
#         | '_ ` _ \ / _ \ / _` |/ _ \ | __/ _ \/ __| __|  | . ` | | |_ |
#         | | | | | | (_) | (_| |  __/ | ||  __/\__ \ |_   | |\  | |__| |
#         |_| |_| |_|\___/ \__,_|\___|_|\__\___||___/\__|  |_| \_|\_____|
# --------------------------------------------------------------------------------
# modeltest x.y.z
# Copyright (C) 2017 Diego Darriba, David Posada, Alexandros Stamatakis
# License GPLv3+: GNU GPL version 3 or later <http://gnu.org/licenses/gpl.html>.
# This is free software: you are free to change and redistribute it.
# There is NO WARRANTY, to the extent permitted by law.
#
# Written by Diego Darriba.
# --------------------------------------------------------------------------------
#
# Physical cores: 1
# Logical cores:  2
# ...

# %%
! modeltest-ng -i sequences_Moskalenko_gr1_muscle.trim.fas -o sequences_Moskalenko_gr1_muscle_trim_modeltest
# Out:
#                              _      _ _            _      _   _  _____
#                             | |    | | |          | |    | \ | |/ ____|
#          _ __ ___   ___   __| | ___| | |_ ___  ___| |_   |  \| | |  __
#         | '_ ` _ \ / _ \ / _` |/ _ \ | __/ _ \/ __| __|  | . ` | | |_ |
#         | | | | | | (_) | (_| |  __/ | ||  __/\__ \ |_   | |\  | |__| |
#         |_| |_| |_|\___/ \__,_|\___|_|\__\___||___/\__|  |_| \_|\_____|
# --------------------------------------------------------------------------------
# modeltest x.y.z
# Copyright (C) 2017 Diego Darriba, David Posada, Alexandros Stamatakis
# License GPLv3+: GNU GPL version 3 or later <http://gnu.org/licenses/gpl.html>.
# This is free software: you are free to change and redistribute it.
# There is NO WARRANTY, to the extent permitted by law.
#
# Written by Diego Darriba.
# --------------------------------------------------------------------------------
#
# Physical cores: 1
# Logical cores:  2
# ...

# %%
! modeltest-ng -i sequences_Moskalenko_gr2_muscle.trim.fas -o sequences_Moskalenko_gr2_muscle_trim_modeltest
# Out:
#                              _      _ _            _      _   _  _____
#                             | |    | | |          | |    | \ | |/ ____|
#          _ __ ___   ___   __| | ___| | |_ ___  ___| |_   |  \| | |  __
#         | '_ ` _ \ / _ \ / _` |/ _ \ | __/ _ \/ __| __|  | . ` | | |_ |
#         | | | | | | (_) | (_| |  __/ | ||  __/\__ \ |_   | |\  | |__| |
#         |_| |_| |_|\___/ \__,_|\___|_|\__\___||___/\__|  |_| \_|\_____|
# --------------------------------------------------------------------------------
# modeltest x.y.z
# Copyright (C) 2017 Diego Darriba, David Posada, Alexandros Stamatakis
# License GPLv3+: GNU GPL version 3 or later <http://gnu.org/licenses/gpl.html>.
# This is free software: you are free to change and redistribute it.
# There is NO WARRANTY, to the extent permitted by law.
#
# Written by Diego Darriba.
# --------------------------------------------------------------------------------
#
# Physical cores: 1
# Logical cores:  2
# ...

# %% [markdown]
# ### When choosing an evolution model , in order to recognize it as the most suitable for our alignment , we will focus on BIC:

# %% [markdown]
# 16S all: Best model according to BIC
# ---------------------------
# Model:              HKY+G4
# lnL:                -6910.4900
# Frequencies:        0.3591 0.0973 0.1715 0.3721
# Subst. Rates:       1.0000 4.7250 1.0000 1.0000 4.7250 1.0000
# Inv. sites prop:    -
# Gamma shape:        0.4191
# Score:              14196.7693
# Weight:             0.4307

# %% [markdown]
# 18S all: Best model according to BIC
# ---------------------------
# Model:              SYM+I+G4
# lnL:                -5660.3527
# Frequencies:        0.2500 0.2500 0.2500 0.2500
# Subst. Rates:       0.3031 0.9080 0.2490 0.1372 2.4808 1.0000
# Inv. sites prop:    0.6260
# Gamma shape:        0.4727
# Score:              11756.3104
# Weight:             0.4806

# %% [markdown]
# 28S all: Best model according to BIC
# ---------------------------
# Model:              TIM3+G4
# lnL:                -5360.3009
# Frequencies:        0.2265 0.2590 0.3062 0.2084
# Subst. Rates:       0.2630 1.2918 1.0000 0.2630 2.8109 1.0000
# Inv. sites prop:    -
# Gamma shape:        0.4140
# Score:              11124.8197
# Weight:             0.8228

# %% [markdown]
# COI all: Best model according to BIC
# ---------------------------
# Model:              TIM2+I+G4
# lnL:                -8183.6188
# Frequencies:        0.3074 0.2047 0.1600 0.3279
# Subst. Rates:       0.4376 5.2126 0.4376 1.0000 14.8110 1.0000
# Inv. sites prop:    0.3368
# Gamma shape:        0.3510
# Score:              16734.4623
# Weight:             0.3697

# %% [markdown]
# eF1a all: Best model according to BIC
# ---------------------------
# Model:              TrNef+G4
# lnL:                -3298.0911
# Frequencies:        0.2500 0.2500 0.2500 0.2500
# Subst. Rates:       1.0000 4.0957 1.0000 1.0000 6.1319 1.0000
# Inv. sites prop:    -
# Gamma shape:        0.5944
# Score:              6813.5644
# Weight:             0.5003

# %% [markdown]
# h3 all: Best model according to BIC
# ---------------------------
# Model:              K80+G4
# lnL:                -994.7166
# Frequencies:        0.2500 0.2500 0.2500 0.2500
# Subst. Rates:       1.0000 2.4974 1.0000 1.0000 2.4974 1.0000
# Inv. sites prop:    -
# Gamma shape:        0.1269
# Score:              2192.4014
# Weight:             0.1988

# %% [markdown]
# all: Best model according to BIC
# ---------------------------
# Model:              TIM3ef+I+G4
# lnL:                -21161.3428
# Frequencies:        0.2500 0.2500 0.2500 0.2500
# Subst. Rates:       0.7518 2.1223 1.0000 0.7518 3.5615 1.0000
# Inv. sites prop:    0.2870
# Gamma shape:        0.6025
# Score:              42477.9931
# Weight:             0.6735

# %% [markdown]
# Group 1: Best model according to BIC
# ---------------------------
# Model:              TIM3ef+I+G4
# lnL:                -16957.0864
# Frequencies:        0.2500 0.2500 0.2500 0.2500
# Subst. Rates:       0.3771 2.6858 1.0000 0.3771 3.4631 1.0000
# Inv. sites prop:    0.5430
# Gamma shape:        0.2510
# Score:              34195.7859
# Weight:             0.5327

# %% [markdown]
# Group 2: Best model according to BIC
# ---------------------------
# Model:              SYM+I+G4
# lnL:                -18973.5073
# Frequencies:        0.2500 0.2500 0.2500 0.2500
# Subst. Rates:       0.9523 3.2106 2.0181 0.4752 4.9480 1.0000
# Inv. sites prop:    0.2886
# Gamma shape:        0.3732
# Score:              38227.3220
# Weight:             0.8765

# %% [markdown]
# ## 6. Let's build an ML tree in RAxML-NG:

# %%
! raxml-ng --msa sequences_Moskalenko_s_16_muscle.trim.fas --model HKY+G4 --prefix Moskalenko_s_16_muscle_raxml --threads 2 --seed 222 
# indicated the correct model that you chose + don't forget about --prefix for convenience
# Out:
# RAxML-NG v. 0.9.0 released on 20.05.2019 by The Exelixis Lab.
# Developed by: Alexey M. Kozlov and Alexandros Stamatakis.
# Contributors: Diego Darriba, Tomas Flouri, Benoit Morel, Sarah Lutteropp, Ben Bettisworth.
# Latest version: https://github.com/amkozlov/raxml-ng
# Questions/problems/suggestions? Please visit: https://groups.google.com/forum/#!forum/raxml
#
# RAxML-NG was called at 21-May-2023 18:44:36 as follows:
#
# raxml-ng --msa sequences_Moskalenko_s_16_muscle.trim.fas --model HKY+G4 --prefix Moskalenko_s_16_muscle_raxml --threads 2 --seed 222
#
# Analysis options:
#   run mode: ML tree search
#   start tree(s): random (10) + parsimony (10)
#   random seed: 222
#   tip-inner: OFF
#   pattern compression: ON
#   per-rate scalers: OFF
#   site repeats: ON
#   fast spr radius: AUTO
#   spr subtree cutoff: 1.000000
#   branch lengths: proportional (ML estimate, algorithm: NR-FAST)
#   SIMD kernels: AVX2
#   parallelization: PTHREADS (2 threads), thread pinning: OFF
#
# ...

# %%
! cat /content/Moskalenko_s_16_muscle_raxml.raxml.mlTrees # trees in newick format - the lengths of branches are specified
# Out:
# (((Gammarus_balcanicus:0.312197,Gammarus_lacustris_1:0.146620):0.067577,Linevichella_vortex:0.408376):0.215530,(((Echiuropus_macronychus:0.085804,Hyalellopsis_carinata:0.225965):0.007480,Macropereiopus_parvus:0.077156):0.022981,Eulimnogammarus_cyaneus:0.051160):0.000001,Hyalella_azteca:2.897661):0.0;
# (Linevichella_vortex:0.414108,(Gammarus_balcanicus:0.316374,Gammarus_lacustris_1:0.149000):0.068001,(Hyalella_azteca:2.962392,(Eulimnogammarus_cyaneus:0.051702,(Macropereiopus_parvus:0.077542,(Hyalellopsis_carinata:0.228441,Echiuropus_macronychus:0.086606):0.007310):0.022886):0.000001):0.218533):0.0;
# (Linevichella_vortex:0.400647,(Gammarus_lacustris_1:0.145831,Gammarus_balcanicus:0.307062):0.066487,(Hyalella_azteca:2.766068,(Eulimnogammarus_cyaneus:0.050423,((Echiuropus_macronychus:0.084715,Hyalellopsis_carinata:0.222585):0.007831,Macropereiopus_parvus:0.076524):0.022902):0.000001):0.213198):0.0;
# ...

# %%
! cat /content/Moskalenko_s_16_muscle_raxml.raxml.bestTree
# Out:
# (Linevichella_vortex:0.414108,(Gammarus_balcanicus:0.316374,Gammarus_lacustris_1:0.149000):0.068001,(Hyalella_azteca:2.962392,(Eulimnogammarus_cyaneus:0.051702,(Macropereiopus_parvus:0.077542,(Hyalellopsis_carinata:0.228441,Echiuropus_macronychus:0.086606):0.007310):0.022886):0.000001):0.218533):0.0;

# %% [markdown]
# ### And we have drawn this ML-tree:

# %% [markdown]
# ![Снимок экрана 2023-05-21 в 22.01.03.png](data:image/png;base64,...)

# %% [markdown]
# ### 6. But we want to optimize, and therefore we will continue to choose the best model for every fas in ModelFinder through the IQ-TREE, and then we build an ML-tree using it

# %%
# !iqtree -m MFP -s sequences_Moskalenko_s_16_muscle.trim.fas --prefix sequences_Moskalenko_s_16_MF2 # even without parallelization, it works faster
# Out:
# IQ-TREE multicore version 2.0.3 for Linux 64-bit built Dec 20 2020
# Developed by Bui Quang Minh, Nguyen Lam Tung, Olga Chernomor,
# Heiko Schmidt, Dominik Schrempf, Michael Woodhams.
#
# Host:    3c051303dba7 (AVX2, FMA3, 12 GB RAM)
# Command: iqtree -m MFP -s sequences_Moskalenko_s_16_muscle.trim.fas --prefix sequences_Moskalenko_s_16_MF2
# Seed:    573383 (Using SPRNG - Scalable Parallel Random Number Generator)
# Time:    Sat May 20 12:44:25 2023
# Kernel:  AVX+FMA - 1 threads (2 CPU cores detected)
#
# HINT: Use -nt option to specify number of threads because your CPU has 2 cores!
# HINT: -nt AUTO will automatically determine the best number of threads to use.
#
# Reading alignment file sequences_Moskalenko_s_16_muscle.trim.fas ... Fasta format detected
# Alignment most likely contains DNA/RNA sequences
# Alignment has 27 sequences with 821 columns, 546 distinct patterns
# 327 parsimony-informative, 238 singleton sites, 256 constant sites
# ...

# %%
# !iqtree -m MFP -s sequences_Moskalenko_s_18_muscle.trim.fas --prefix sequences_Moskalenko_s_18_MF2
# Out:
# IQ-TREE multicore version 2.0.3 for Linux 64-bit built Dec 20 2020
# Developed by Bui Quang Minh, Nguyen Lam Tung, Olga Chernomor,
# Heiko Schmidt, Dominik Schrempf, Michael Woodhams.
#
# Host:    3c051303dba7 (AVX2, FMA3, 12 GB RAM)
# Command: iqtree -m MFP -s sequences_Moskalenko_s_18_muscle.trim.fas --prefix sequences_Moskalenko_s_18_MF2
# Seed:    533010 (Using SPRNG - Scalable Parallel Random Number Generator)
# Time:    Sat May 20 12:44:53 2023
# Kernel:  AVX+FMA - 1 threads (2 CPU cores detected)
#
# HINT: Use -nt option to specify number of threads because your CPU has 2 cores!
# HINT: -nt AUTO will automatically determine the best number of threads to use.
#
# Reading alignment file sequences_Moskalenko_s_18_muscle.trim.fas ... Fasta format detected
# Alignment most likely contains DNA/RNA sequences
# Alignment has 27 sequences with 1827 columns, 240 distinct patterns
# 100 parsimony-informative, 347 singleton sites, 1380 constant sites
# ...

# %%
# !iqtree -m MFP -s sequences_Moskalenko_s_28_muscle.trim.fas --prefix sequences_Moskalenko_s_28_MF2
# Out:
# IQ-TREE multicore version 2.0.3 for Linux 64-bit built Dec 20 2020
# Developed by Bui Quang Minh, Nguyen Lam Tung, Olga Chernomor,
# Heiko Schmidt, Dominik Schrempf, Michael Woodhams.
#
# Host:    3c051303dba7 (AVX2, FMA3, 12 GB RAM)
# Command: iqtree -m MFP -s sequences_Moskalenko_s_28_muscle.trim.fas --prefix sequences_Moskalenko_s_28_MF2
# Seed:    898301 (Using SPRNG - Scalable Parallel Random Number Generator)
# Time:    Sat May 20 12:45:00 2023
# Kernel:  AVX+FMA - 1 threads (2 CPU cores detected)
#
# HINT: Use -nt option to specify number of threads because your CPU has 2 cores!
# HINT: -nt AUTO will automatically determine the best number of threads to use.
#
# Reading alignment file sequences_Moskalenko_s_28_muscle.trim.fas ... Fasta format detected
# Alignment most likely contains DNA/RNA sequences
# Alignment has 26 sequences with 1364 columns, 384 distinct patterns
# 146 parsimony-informative, 500 singleton sites, 718 constant sites
# ...

# %%
# !iqtree -m MFP -s sequences_Moskalenko_coi_muscle.trim.fas --prefix sequences_Moskalenko_coi_MF2
# Out:
# IQ-TREE multicore version 2.0.3 for Linux 64-bit built Dec 20 2020
# Developed by Bui Quang Minh, Nguyen Lam Tung, Olga Chernomor,
# Heiko Schmidt, Dominik Schrempf, Michael Woodhams.
#
# Host:    3c051303dba7 (AVX2, FMA3, 12 GB RAM)
# Command: iqtree -m MFP -s sequences_Moskalenko_coi_muscle.trim.fas --prefix sequences_Moskalenko_coi_MF2
# Seed:    60933 (Using SPRNG - Scalable Parallel Random Number Generator)
# Time:    Sat May 20 12:45:11 2023
# Kernel:  AVX+FMA - 1 threads (2 CPU cores detected)
#
# HINT: Use -nt option to specify number of threads because your CPU has 2 cores!
# HINT: -nt AUTO will automatically determine the best number of threads to use.
#
# Reading alignment file sequences_Moskalenko_coi_muscle.trim.fas ... Fasta format detected
# Alignment most likely contains DNA/RNA sequences
# Alignment has 26 sequences with 628 columns, 359 distinct patterns
# 291 parsimony-informative, 44 singleton sites, 293 constant sites
# ...

# %%
# !iqtree -m MFP -s sequences_Moskalenko_eF1a_muscle.trim.fas --prefix sequences_Moskalenko_eF1a_MF2
# Out:
# IQ-TREE multicore version 2.0.3 for Linux 64-bit built Dec 20 2020
# Developed by Bui Quang Minh, Nguyen Lam Tung, Olga Chernomor,
# Heiko Schmidt, Dominik Schrempf, Michael Woodhams.
#
# Host:    3c051303dba7 (AVX2, FMA3, 12 GB RAM)
# Command: iqtree -m MFP -s sequences_Moskalenko_eF1a_muscle.trim.fas --prefix sequences_Moskalenko_eF1a_MF2
# Seed:    797361 (Using SPRNG - Scalable Parallel Random Number Generator)
# Time:    Sat May 20 12:45:33 2023
# Kernel:  AVX+FMA - 1 threads (2 CPU cores detected)
#
# HINT: Use -nt option to specify number of threads because your CPU has 2 cores!
# HINT: -nt AUTO will automatically determine the best number of threads to use.
#
# Reading alignment file sequences_Moskalenko_eF1a_muscle.trim.fas ... Fasta format detected
# Alignment most likely contains DNA/RNA sequences
# Alignment has 17 sequences with 598 columns, 229 distinct patterns
# 319 parsimony-informative, 54 singleton sites, 225 constant sites
# ...

# %%
# !iqtree -m MFP -s sequences_Moskalenko_h3_muscle.trim.fas --prefix sequences_Moskalenko_h3_MF2
# Out:
# IQ-TREE multicore version 2.0.3 for Linux 64-bit built Dec 20 2020
# Developed by Bui Quang Minh, Nguyen Lam Tung, Olga Chernomor,
# Heiko Schmidt, Dominik Schrempf, Michael Woodhams.
#
# Host:    3c051303dba7 (AVX2, FMA3, 12 GB RAM)
# Command: iqtree -m MFP -s sequences_Moskalenko_h3_muscle.trim.fas --prefix sequences_Moskalenko_h3_MF2
# Seed:    538969 (Using SPRNG - Scalable Parallel Random Number Generator)
# Time:    Sat May 20 12:45:36 2023
# Kernel:  AVX+FMA - 1 threads (2 CPU cores detected)
#
# HINT: Use -nt option to specify number of threads because your CPU has 2 cores!
# HINT: -nt AUTO will automatically determine the best number of threads to use.
#
# Reading alignment file sequences_Moskalenko_h3_muscle.trim.fas ... Fasta format detected
# Alignment most likely contains DNA/RNA sequences
# Alignment has 18 sequences with 330 columns, 55 distinct patterns
# 26 parsimony-informative, 41 singleton sites, 263 constant sites
# ...

# %%
# !iqtree -m MFP -s sequences_Moskalenko_all_muscle.trim.fas --prefix sequences_Moskalenko_all_muscle_MF2
# Out:
# IQ-TREE multicore version 2.0.3 for Linux 64-bit built Dec 20 2020
# Developed by Bui Quang Minh, Nguyen Lam Tung, Olga Chernomor,
# Heiko Schmidt, Dominik Schrempf, Michael Woodhams.
#
# Host:    926634e79096 (AVX2, FMA3, 12 GB RAM)
# Command: iqtree -m MFP -s sequences_Moskalenko_all_muscle.trim.fas --prefix sequences_Moskalenko_all_muscle_MF2
# Seed:    286442 (Using SPRNG - Scalable Parallel Random Number Generator)
# Time:    Sun May 21 19:43:28 2023
# Kernel:  AVX+FMA - 1 threads (2 CPU cores detected)
#
# HINT: Use -nt option to specify number of threads because your CPU has 2 cores!
# HINT: -nt AUTO will automatically determine the best number of threads to use.
#
# Reading alignment file sequences_Moskalenko_all_muscle.trim.fas ... Fasta format detected
# Alignment most likely contains DNA/RNA sequences
# Alignment has 8 sequences with 5587 columns, 903 distinct patterns
# 722 parsimony-informative, 1234 singleton sites, 3631 constant sites
# ...

# %%
# !iqtree -m MFP -s sequences_Moskalenko_gr1_muscle.trim.fas --prefix sequences_Moskalenko_gr1_muscle_MF2
# Out:
# IQ-TREE multicore version 2.0.3 for Linux 64-bit built Dec 20 2020
# Developed by Bui Quang Minh, Nguyen Lam Tung, Olga Chernomor,
# Heiko Schmidt, Dominik Schrempf, Michael Woodhams.
#
# Host:    926634e79096 (AVX2, FMA3, 12 GB RAM)
# Command: iqtree -m MFP -s sequences_Moskalenko_gr1_muscle.trim.fas --prefix sequences_Moskalenko_gr1_muscle_MF2
# Seed:    54052 (Using SPRNG - Scalable Parallel Random Number Generator)
# Time:    Sun May 21 19:43:38 2023
# Kernel:  AVX+FMA - 1 threads (2 CPU cores detected)
#
# HINT: Use -nt option to specify number of threads because your CPU has 2 cores!
# HINT: -nt AUTO will automatically determine the best number of threads to use.
#
# Reading alignment file sequences_Moskalenko_gr1_muscle.trim.fas ... Fasta format detected
# Alignment most likely contains DNA/RNA sequences
# Alignment has 16 sequences with 3955 columns, 703 distinct patterns
# 507 parsimony-informative, 569 singleton sites, 2879 constant sites
# ...

# %%
# !iqtree -m MFP -s sequences_Moskalenko_gr2_muscle.trim.fas --prefix sequences_Moskalenko_gr2_muscle_MF2
# Out:
# IQ-TREE multicore version 2.0.3 for Linux 64-bit built Dec 20 2020
# Developed by Bui Quang Minh, Nguyen Lam Tung, Olga Chernomor,
# Heiko Schmidt, Dominik Schrempf, Michael Woodhams.
#
# Host:    926634e79096 (AVX2, FMA3, 12 GB RAM)
# Command: iqtree -m MFP -s sequences_Moskalenko_gr2_muscle.trim.fas --prefix sequences_Moskalenko_gr2_muscle_MF2
# Seed:    901065 (Using SPRNG - Scalable Parallel Random Number Generator)
# Time:    Sun May 21 19:43:45 2023
# Kernel:  AVX+FMA - 1 threads (2 CPU cores detected)
#
# HINT: Use -nt option to specify number of threads because your CPU has 2 cores!
# HINT: -nt AUTO will automatically determine the best number of threads to use.
#
# Reading alignment file sequences_Moskalenko_gr2_muscle.trim.fas ... Fasta format detected
# Alignment most likely contains DNA/RNA sequences
# Alignment has 15 sequences with 3806 columns, 905 distinct patterns
# 607 parsimony-informative, 774 singleton sites, 2425 constant sites
# ...

# %% [markdown]
# ### ModelFinder results:

# %% [markdown]
# Best-fit model: TPM3+F+G4 chosen according to BIC (S16 all)
#
# Best-fit model: GTR+F+R2 chosen according to BIC (S18 all)
#
# Best-fit model: TIM3+F+R2 chosen according to BIC (S28 all)
#
# Best-fit model: TN+F+I+G4 chosen according to BIC (coi)
#
# Best-fit model: K2P+R2 chosen according to BIC (eF1a)
#
# Best-fit model: TNe+R2 chosen according to BIC (H3)
#
# Best-fit model: TNe+R2 chosen according to BIC (All)
#
# Best-fit model: TIM3e+R3 chosen according to BIC (Group 1)
#
# Best-fit model: SYM+R2 chosen according to BIC (Group 2)

# %% [markdown]
# In general, since we decide that it is the BIC parmeter that is important to us, we believe that both programs have come to about the same thing

# %% [markdown]
# ### Building an ML-tree in an IQ-TREE using selected models

# %%
! iqtree -m TPM3+F+G4 -s sequences_Moskalenko_s_16_muscle.trim.fas --prefix sequences_Moskalenko_s_16_iqtree
# Out:
# IQ-TREE multicore version 2.0.3 for Linux 64-bit built Dec 20 2020
# Developed by Bui Quang Minh, Nguyen Lam Tung, Olga Chernomor,
# Heiko Schmidt, Dominik Schrempf, Michael Woodhams.
#
# Host:    926634e79096 (AVX2, FMA3, 12 GB RAM)
# Command: iqtree -m TPM3+F+G4 -s sequences_Moskalenko_s_16_muscle.trim.fas --prefix sequences_Moskalenko_s_16_iqtree
# Seed:    245993 (Using SPRNG - Scalable Parallel Random Number Generator)
# Time:    Sun May 21 20:10:37 2023
# Kernel:  AVX+FMA - 1 threads (2 CPU cores detected)
#
# HINT: Use -nt option to specify number of threads because your CPU has 2 cores!
# HINT: -nt AUTO will automatically determine the best number of threads to use.
#
# Reading alignment file sequences_Moskalenko_s_16_muscle.trim.fas ... Fasta format detected
# Alignment most likely contains DNA/RNA sequences
# Alignment has 8 sequences with 429 columns, 158 distinct patterns
# 95 parsimony-informative, 94 singleton sites, 240 constant sites
# ...

# %%
! cat sequences_Moskalenko_s_16_iqtree.iqtree
# Out:
# IQ-TREE 2.0.3 built Dec 20 2020
#
# Input file name: sequences_Moskalenko_s_16_muscle.trim.fas
# Type of analysis: tree reconstruction
# Random seed number: 245993
#
# REFERENCES
# ----------
#
# To cite IQ-TREE please use:
#
# Bui Quang Minh, Heiko A. Schmidt, Olga Chernomor, Dominik Schrempf,
# Michael D. Woodhams, Arndt von Haeseler, and Robert Lanfear (2020)
# IQ-TREE 2: New models and efficient methods for phylogenetic inference
# in the genomic era. Mol. Biol. Evol., in press.
# https://doi.org/10.1093/molbev/msaa015
#
# SEQUENCE ALIGNMENT
# ------------------
#
# Input data: 8 sequences with 429 nucleotide sites
# Number of constant sites: 240 (= 55.9441% of all sites)
# Number of invariant (constant or ambiguous constant) sites: 240 (= 55.9441% of all sites)
# Number of parsimony informative sites: 95
# Number of distinct site patterns: 158
#
# SUBSTITUTION PROCESS
# --------------------
#
# Model of substitution: TPM3+F+G4
#
# Rate parameter R:
#
#   A-C: 0.2483
# ...

# %%
! cat sequences_Moskalenko_s_16_iqtree.treefile # the topology matches the previous result (the topology was seen in the previous cell)
# Out:
# (Hyalella_azteca:2.5772119970,((Gammarus_balcanicus:0.2757422106,Gammarus_lacustris_1:0.1380672091):0.0549396822,Linevichella_vortex:0.3463080994):0.1983620639,(((Hyalellopsis_carinata:0.2193436986,Echiuropus_macronychus:0.0782782105):0.0078268780,Macropereiopus_parvus:0.0752156041):0.0214842836,Eulimnogammarus_cyaneus:0.0474966045):0.0000023107);

# %%
! iqtree -m GTR+F+R2 -s sequences_Moskalenko_s_18_muscle.trim.fas --prefix sequences_Moskalenko_s_18_iqtree
# Out:
# IQ-TREE multicore version 2.0.3 for Linux 64-bit built Dec 20 2020
# Developed by Bui Quang Minh, Nguyen Lam Tung, Olga Chernomor,
# Heiko Schmidt, Dominik Schrempf, Michael Woodhams.
#
# Host:    926634e79096 (AVX2, FMA3, 12 GB RAM)
# Command: iqtree -m GTR+F+R2 -s sequences_Moskalenko_s_18_muscle.trim.fas --prefix sequences_Moskalenko_s_18_iqtree
# Seed:    978676 (Using SPRNG - Scalable Parallel Random Number Generator)
# Time:    Sun May 21 20:19:51 2023
# Kernel:  AVX+FMA - 1 threads (2 CPU cores detected)
#
# HINT: Use -nt option to specify number of threads because your CPU has 2 cores!
# HINT: -nt AUTO will automatically determine the best number of threads to use.
#
# Reading alignment file sequences_Moskalenko_s_18_muscle.trim.fas ... Fasta format detected
# Alignment most likely contains DNA/RNA sequences
# Alignment has 8 sequences with 2114 columns, 168 distinct patterns
# 52 parsimony-informative, 398 singleton sites, 1664 constant sites
# ...

# %%
! cat sequences_Moskalenko_s_18_iqtree.iqtree
# Out:
# IQ-TREE 2.0.3 built Dec 20 2020
#
# Input file name: sequences_Moskalenko_s_18_muscle.trim.fas
# Type of analysis: tree reconstruction
# Random seed number: 978676
#
# REFERENCES
# ----------
#
# To cite IQ-TREE please use:
#
# Bui Quang Minh, Heiko A. Schmidt, Olga Chernomor, Dominik Schrempf,
# Michael D. Woodhams, Arndt von Haeseler, and Robert Lanfear (2020)
# IQ-TREE 2: New models and efficient methods for phylogenetic inference
# in the genomic era. Mol. Biol. Evol., in press.
# https://doi.org/10.1093/molbev/msaa015
#
# SEQUENCE ALIGNMENT
# ------------------
#
# Input data: 8 sequences with 2114 nucleotide sites
# Number of constant sites: 1664 (= 78.7133% of all sites)
# Number of invariant (constant or ambiguous constant) sites: 1664 (= 78.7133% of all sites)
# Number of parsimony informative sites: 52
# Number of distinct site patterns: 168
#
# SUBSTITUTION PROCESS
# --------------------
#
# Model of substitution: GTR+F+R2
#
# Rate parameter R:
#
#   A-C: 0.7438
# ...

# %%
! cat sequences_Moskalenko_s_18_iqtree.treefile
# Out:
# (Hyalella_azteca:0.5622540415,(((Dikerogammarus_villosus:0.0569682423,((Hyalellopsis_carinata:0.0035195397,Echiuropus_macronychus:0.0016901077):0.0012613514,Eulimnogammarus_cyaneus:0.0024458078):0.0055206705):0.0066057975,Gammarus_lacustris_1:0.0081979380):0.0031093971,Linevichella_vortex:0.0112269135):0.0037105255,Gammarus_balcanicus:0.0058442523);

# %%
! iqtree -m TIM3+F+R2 -s sequences_Moskalenko_s_28_muscle.trim.fas --prefix sequences_Moskalenko_s_28_iqtree -redo
# Out:
# IQ-TREE multicore version 2.0.3 for Linux 64-bit built Dec 20 2020
# Developed by Bui Quang Minh, Nguyen Lam Tung, Olga Chernomor,
# Heiko Schmidt, Dominik Schrempf, Michael Woodhams.
#
# Host:    926634e79096 (AVX2, FMA3, 12 GB RAM)
# Command: iqtree -m TIM3+F+R2 -s sequences_Moskalenko_s_28_muscle.trim.fas --prefix sequences_Moskalenko_s_28_iqtree -redo
# Seed:    456098 (Using SPRNG - Scalable Parallel Random Number Generator)
# Time:    Sun May 21 20:23:30 2023
# Kernel:  AVX+FMA - 1 threads (2 CPU cores detected)
#
# HINT: Use -nt option to specify number of threads because your CPU has 2 cores!
# HINT: -nt AUTO will automatically determine the best number of threads to use.
#
# Reading alignment file sequences_Moskalenko_s_28_muscle.trim.fas ... Fasta format detected
# Alignment most likely contains DNA/RNA sequences
# Alignment has 8 sequences with 373 columns, 42 distinct patterns
# 10 parsimony-informative, 53 singleton sites, 310 constant sites
# ...

# %%
! cat sequences_Moskalenko_s_28_iqtree.iqtree
# Out:
# IQ-TREE 2.0.3 built Dec 20 2020
#
# Input file name: sequences_Moskalenko_s_28_muscle.trim.fas
# Type of analysis: tree reconstruction
# Random seed number: 456098
#
# REFERENCES
# ----------
#
# To cite IQ-TREE please use:
#
# Bui Quang Minh, Heiko A. Schmidt, Olga Chernomor, Dominik Schrempf,
# Michael D. Woodhams, Arndt von Haeseler, and Robert Lanfear (2020)
# IQ-TREE 2: New models and efficient methods for phylogenetic inference
# in the genomic era. Mol. Biol. Evol., in press.
# https://doi.org/10.1093/molbev/msaa015
#
# SEQUENCE ALIGNMENT
# ------------------
#
# Input data: 8 sequences with 373 nucleotide sites
# Number of constant sites: 310 (= 83.1099% of all sites)
# Number of invariant (constant or ambiguous constant) sites: 310 (= 83.1099% of all sites)
# Number of parsimony informative sites: 10
# Number of distinct site patterns: 42
#
# SUBSTITUTION PROCESS
# --------------------
#
# Model of substitution: TIM3+F+R2
#
# Rate parameter R:
#
#   A-C: 0.5389
# ...

# %%
! cat sequences_Moskalenko_s_28_iqtree.treefile
# Out:
# (Hyalella_azteca:0.2232740340,Gammarus_balcanicus:0.0188945639,((Gammarus_lacustris_1:0.0028716651,Linevichella_vortex:0.0053604891):0.0035921468,(((Echiuropus_macronychus:0.0000000000,Eulimnogammarus_cyaneus:0.0000000000):0.0000012171,Hyalellopsis_carinata:0.0000012171):0.0000012171,Macropereiopus_parvus:0.0027043842):0.0048800122):0.0158361268);

# %%
! iqtree -m TN+F+I+G4 -s sequences_Moskalenko_coi_muscle.trim.fas --prefix sequences_Moskalenko_coi_iqtree -redo
# Out:
# IQ-TREE multicore version 2.0.3 for Linux 64-bit built Dec 20 2020
# Developed by Bui Quang Minh, Nguyen Lam Tung, Olga Chernomor,
# Heiko Schmidt, Dominik Schrempf, Michael Woodhams.
#
# Host:    926634e79096 (AVX2, FMA3, 12 GB RAM)
# Command: iqtree -m TN+F+I+G4 -s sequences_Moskalenko_coi_muscle.trim.fas --prefix sequences_Moskalenko_coi_iqtree -redo
# Seed:    479361 (Using SPRNG - Scalable Parallel Random Number Generator)
# Time:    Sun May 21 20:31:22 2023
# Kernel:  AVX+FMA - 1 threads (2 CPU cores detected)
#
# HINT: Use -nt option to specify number of threads because your CPU has 2 cores!
# HINT: -nt AUTO will automatically determine the best number of threads to use.
#
# Reading alignment file sequences_Moskalenko_coi_muscle.trim.fas ... Fasta format detected
# Alignment most likely contains DNA/RNA sequences
# Alignment has 8 sequences with 688 columns, 271 distinct patterns
# 216 parsimony-informative, 83 singleton sites, 389 constant sites
# ...

# %%
! cat sequences_Moskalenko_coi_iqtree.iqtree
# Out:
# IQ-TREE 2.0.3 built Dec 20 2020
#
# Input file name: sequences_Moskalenko_coi_muscle.trim.fas
# Type of analysis: tree reconstruction
# Random seed number: 479361
#
# REFERENCES
# ----------
#
# To cite IQ-TREE please use:
#
# Bui Quang Minh, Heiko A. Schmidt, Olga Chernomor, Dominik Schrempf,
# Michael D. Woodhams, Arndt von Haeseler, and Robert Lanfear (2020)
# IQ-TREE 2: New models and efficient methods for phylogenetic inference
# in the genomic era. Mol. Biol. Evol., in press.
# https://doi.org/10.1093/molbev/msaa015
#
# SEQUENCE ALIGNMENT
# ------------------
#
# Input data: 8 sequences with 688 nucleotide sites
# Number of constant sites: 389 (= 56.5407% of all sites)
# Number of invariant (constant or ambiguous constant) sites: 389 (= 56.5407% of all sites)
# Number of parsimony informative sites: 216
# Number of distinct site patterns: 271
#
# SUBSTITUTION PROCESS
# --------------------
#
# Model of substitution: TN+F+I+G4
#
# Rate parameter R:
#
#   A-C: 1.0000
# ...

# %%
! cat sequences_Moskalenko_coi_iqtree.treefile
# Out:
# (Hyalella_azteca:1.0059218252,((Gammarus_balcanicus:0.5167109617,Linevichella_vortex:0.5652208276):0.0684645730,((Hyalellopsis_carinata:0.7076705430,Echiuropus_macronychus:0.1586369324):0.0843803615,(Macropereiopus_parvus:0.2423728956,Eulimnogammarus_cyaneus:0.3767738488):0.0527029968):0.3163686287):0.2131749448,Gammarus_lacustris_1:0.2138864237);

# %%
! iqtree -m K2P+R2 -s sequences_Moskalenko_eF1a_muscle.trim.fas --prefix sequences_Moskalenko_eF1a_iqtree -redo
# Out:
# IQ-TREE multicore version 2.0.3 for Linux 64-bit built Dec 20 2020
# Developed by Bui Quang Minh, Nguyen Lam Tung, Olga Chernomor,
# Heiko Schmidt, Dominik Schrempf, Michael Woodhams.
#
# Host:    926634e79096 (AVX2, FMA3, 12 GB RAM)
# Command: iqtree -m K2P+R2 -s sequences_Moskalenko_eF1a_muscle.trim.fas --prefix sequences_Moskalenko_eF1a_iqtree -redo
# Seed:    907990 (Using SPRNG - Scalable Parallel Random Number Generator)
# Time:    Sun May 21 20:33:19 2023
# Kernel:  AVX+FMA - 1 threads (2 CPU cores detected)
#
# HINT: Use -nt option to specify number of threads because your CPU has 2 cores!
# HINT: -nt AUTO will automatically determine the best number of threads to use.
#
# Reading alignment file sequences_Moskalenko_eF1a_muscle.trim.fas ... Fasta format detected
# Alignment most likely contains DNA/RNA sequences
# Alignment has 8 sequences with 1546 columns, 440 distinct patterns
# 339 parsimony-informative, 587 singleton sites, 620 constant sites
# ...

# %%
! cat sequences_Moskalenko_eF1a_iqtree.iqtree
# Out:
# IQ-TREE 2.0.3 built Dec 20 2020
#
# Input file name: sequences_Moskalenko_eF1a_muscle.trim.fas
# Type of analysis: tree reconstruction
# Random seed number: 907990
#
# REFERENCES
# ----------
#
# To cite IQ-TREE please use:
#
# Bui Quang Minh, Heiko A. Schmidt, Olga Chernomor, Dominik Schrempf,
# Michael D. Woodhams, Arndt von Haeseler, and Robert Lanfear (2020)
# IQ-TREE 2: New models and efficient methods for phylogenetic inference
# in the genomic era. Mol. Biol. Evol., in press.
# https://doi.org/10.1093/molbev/msaa015
#
# SEQUENCE ALIGNMENT
# ------------------
#
# Input data: 8 sequences with 1546 nucleotide sites
# Number of constant sites: 620 (= 40.1035% of all sites)
# Number of invariant (constant or ambiguous constant) sites: 620 (= 40.1035% of all sites)
# Number of parsimony informative sites: 339
# Number of distinct site patterns: 440
#
# SUBSTITUTION PROCESS
# --------------------
#
# Model of substitution: K2P+R2
#
# Rate parameter R:
#
#   A-C: 1.0000
# ...

# %%
! cat sequences_Moskalenko_eF1a_iqtree.treefile
# Out:
# (Gammarus_lacustris_1:4.0826638817,(((Hyalella_azteca:0.2499116534,(Hyalellopsis_carinata:0.0484229907,(Macropereiopus_parvus:0.0050246502,Eulimnogammarus_cyaneus:0.0186735104):0.0973324176):0.0581936012):0.0827347515,Linevichella_vortex:0.0676818281):0.0156005637,Gammarus_balcanicus:0.0410537350):0.0070214819,Echiuropus_macronychus:0.0569711681);

# %%
! iqtree -m TNe+R2  -s sequences_Moskalenko_h3_muscle.trim.fas --prefix sequences_Moskalenko_h3_iqtree -redo
# Out:
# IQ-TREE multicore version 2.0.3 for Linux 64-bit built Dec 20 2020
# Developed by Bui Quang Minh, Nguyen Lam Tung, Olga Chernomor,
# Heiko Schmidt, Dominik Schrempf, Michael Woodhams.
#
# Host:    926634e79096 (AVX2, FMA3, 12 GB RAM)
# Command: iqtree -m TNe+R2 -s sequences_Moskalenko_h3_muscle.trim.fas --prefix sequences_Moskalenko_h3_iqtree -redo
# Seed:    466313 (Using SPRNG - Scalable Parallel Random Number Generator)
# Time:    Sun May 21 20:38:07 2023
# Kernel:  AVX+FMA - 1 threads (2 CPU cores detected)
#
# HINT: Use -nt option to specify number of threads because your CPU has 2 cores!
# HINT: -nt AUTO will automatically determine the best number of threads to use.
#
# Reading alignment file sequences_Moskalenko_h3_muscle.trim.fas ... Fasta format detected
# Alignment most likely contains DNA/RNA sequences
# Alignment has 8 sequences with 330 columns, 45 distinct patterns
# 19 parsimony-informative, 44 singleton sites, 267 constant sites
# ...

# %%
! cat sequences_Moskalenko_h3_iqtree.iqtree
# Out:
# IQ-TREE 2.0.3 built Dec 20 2020
#
# Input file name: sequences_Moskalenko_h3_muscle.trim.fas
# Type of analysis: tree reconstruction
# Random seed number: 466313
#
# REFERENCES
# ----------
#
# To cite IQ-TREE please use:
#
# Bui Quang Minh, Heiko A. Schmidt, Olga Chernomor, Dominik Schrempf,
# Michael D. Woodhams, Arndt von Haeseler, and Robert Lanfear (2020)
# IQ-TREE 2: New models and efficient methods for phylogenetic inference
# in the genomic era. Mol. Biol. Evol., in press.
# https://doi.org/10.1093/molbev/msaa015
#
# SEQUENCE ALIGNMENT
# ------------------
#
# Input data: 8 sequences with 330 nucleotide sites
# Number of constant sites: 267 (= 80.9091% of all sites)
# Number of invariant (constant or ambiguous constant) sites: 267 (= 80.9091% of all sites)
# Number of parsimony informative sites: 19
# Number of distinct site patterns: 45
#
# SUBSTITUTION PROCESS
# --------------------
#
# Model of substitution: TNe+R2
#
# Rate parameter R:
#
#   A-C: 1.0000
#   A-G: 1.3264
# ...

# %%
! cat sequences_Moskalenko_h3_iqtree.treefile
# Out:
# (Hyalella_azteca:0.1811867071,Linevichella_vortex:0.0417734075,(Gammarus_balcanicus:0.0177923945,((Gammarus_lacustris_1:0.0187418412,Echiuropus_macronychus:0.0000010339):0.0026323869,((Macropereiopus_parvus:0.0113861386,Eulimnogammarus_cyaneus:0.0000010339):0.0036967047,Hyalellopsis_carinata:0.0029129549):0.0032292890):0.0164458726):0.0161569215);

# %%
! iqtree -m TNe+R2  -s sequences_Moskalenko_all_muscle.trim.fas --prefix sequences_Moskalenko_all_iqtree -redo
# Out:
# IQ-TREE multicore version 2.0.3 for Linux 64-bit built Dec 20 2020
# Developed by Bui Quang Minh, Nguyen Lam Tung, Olga Chernomor,
# Heiko Schmidt, Dominik Schrempf, Michael Woodhams.
#
# Host:    926634e79096 (AVX2, FMA3, 12 GB RAM)
# Command: iqtree -m TNe+R2 -s sequences_Moskalenko_all_muscle.trim.fas --prefix sequences_Moskalenko_all_iqtree -redo
# Seed:    825088 (Using SPRNG - Scalable Parallel Random Number Generator)
# Time:    Sun May 21 20:38:23 2023
# Kernel:  AVX+FMA - 1 threads (2 CPU cores detected)
#
# HINT: Use -nt option to specify number of threads because your CPU has 2 cores!
# HINT: -nt AUTO will automatically determine the best number of threads to use.
#
# Reading alignment file sequences_Moskalenko_all_muscle.trim.fas ... Fasta format detected
# Alignment most likely contains DNA/RNA sequences
# Alignment has 8 sequences with 5587 columns, 903 distinct patterns
# 722 parsimony-informative, 1234 singleton sites, 3631 constant sites
# ...

# %%
! cat sequences_Moskalenko_all_iqtree.iqtree
# Out:
# IQ-TREE 2.0.3 built Dec 20 2020
#
# Input file name: sequences_Moskalenko_all_muscle.trim.fas
# Type of analysis: tree reconstruction
# Random seed number: 825088
#
# REFERENCES
# ----------
#
# To cite IQ-TREE please use:
#
# Bui Quang Minh, Heiko A. Schmidt, Olga Chernomor, Dominik Schrempf,
# Michael D. Woodhams, Arndt von Haeseler, and Robert Lanfear (2020)
# IQ-TREE 2: New models and efficient methods for phylogenetic inference
# in the genomic era. Mol. Biol. Evol., in press.
# https://doi.org/10.1093/molbev/msaa015
#
# SEQUENCE ALIGNMENT
# ------------------
#
# Input data: 8 sequences with 5587 nucleotide sites
# Number of constant sites: 3631 (= 64.9902% of all sites)
# Number of invariant (constant or ambiguous constant) sites: 3631 (= 64.9902% of all sites)
# Number of parsimony informative sites: 722
# Number of distinct site patterns: 903
#
# SUBSTITUTION PROCESS
# --------------------
#
# Model of substitution: TNe+R2
#
# Rate parameter R:
#
#   A-C: 1.0000
# ...

# %%
! cat sequences_Moskalenko_all_iqtree.treefile
# Out:
# (Gammarus_lacustris_1:0.4413039628,((Hyalella_azteca:0.6056512825,(Hyalellopsis_carinata:0.0664724949,(Macropereiopus_parvus:0.0221182142,Eulimnogammarus_cyaneus:0.0255229855):0.0255822278):0.0182664058):0.0240910796,Echiuropus_macronychus:0.0269517381):0.0228371803,(Linevichella_vortex:0.0657136603,Gammarus_balcanicus:0.0631922701):0.0171657414);

# %%
! iqtree -m TIM3e+R3  -s sequences_Moskalenko_gr1_muscle.trim.fas --prefix sequences_Moskalenko_gr1_iqtree -redo
# Out:
# IQ-TREE multicore version 2.0.3 for Linux 64-bit built Dec 20 2020
# Developed by Bui Quang Minh, Nguyen Lam Tung, Olga Chernomor,
# Heiko Schmidt, Dominik Schrempf, Michael Woodhams.
#
# Host:    926634e79096 (AVX2, FMA3, 12 GB RAM)
# Command: iqtree -m TIM3e+R3 -s sequences_Moskalenko_gr1_muscle.trim.fas --prefix sequences_Moskalenko_gr1_iqtree -redo
# Seed:    307857 (Using SPRNG - Scalable Parallel Random Number Generator)
# Time:    Sun May 21 20:38:35 2023
# Kernel:  AVX+FMA - 1 threads (2 CPU cores detected)
#
# HINT: Use -nt option to specify number of threads because your CPU has 2 cores!
# HINT: -nt AUTO will automatically determine the best number of threads to use.
#
# Reading alignment file sequences_Moskalenko_gr1_muscle.trim.fas ... Fasta format detected
# Alignment most likely contains DNA/RNA sequences
# Alignment has 16 sequences with 3955 columns, 703 distinct patterns
# 507 parsimony-informative, 569 singleton sites, 2879 constant sites
# ...

# %%
! cat sequences_Moskalenko_gr1_iqtree.iqtree
# Out:
# IQ-TREE 2.0.3 built Dec 20 2020
#
# Input file name: sequences_Moskalenko_gr1_muscle.trim.fas
# Type of analysis: tree reconstruction
# Random seed number: 307857
#
# REFERENCES
# ----------
#
# To cite IQ-TREE please use:
#
# Bui Quang Minh, Heiko A. Schmidt, Olga Chernomor, Dominik Schrempf,
# Michael D. Woodhams, Arndt von Haeseler, and Robert Lanfear (2020)
# IQ-TREE 2: New models and efficient methods for phylogenetic inference
# in the genomic era. Mol. Biol. Evol., in press.
# https://doi.org/10.1093/molbev/msaa015
#
# SEQUENCE ALIGNMENT
# ------------------
#
# Input data: 16 sequences with 3955 nucleotide sites
# Number of constant sites: 2879 (= 72.7939% of all sites)
# Number of invariant (constant or ambiguous constant) sites: 2879 (= 72.7939% of all sites)
# Number of parsimony informative sites: 507
# Number of distinct site patterns: 703
#
# SUBSTITUTION PROCESS
# --------------------
#
# Model of substitution: TIM3e+R3
#
# Rate parameter R:
#
#   A-C: 0.5146
# ...

# %%
! cat sequences_Moskalenko_gr1_iqtree.iqtree
# Out:
# IQ-TREE 2.0.3 built Dec 20 2020
#
# Input file name: sequences_Moskalenko_gr1_muscle.trim.fas
# Type of analysis: tree reconstruction
# Random seed number: 307857
#
# REFERENCES
# ----------
#
# To cite IQ-TREE please use:
#
# Bui Quang Minh, Heiko A. Schmidt, Olga Chernomor, Dominik Schrempf,
# Michael D. Woodhams, Arndt von Haeseler, and Robert Lanfear (2020)
# IQ-TREE 2: New models and efficient methods for phylogenetic inference
# in the genomic era. Mol. Biol. Evol., in press.
# https://doi.org/10.1093/molbev/msaa015
#
# SEQUENCE ALIGNMENT
# ------------------
#
# Input data: 16 sequences with 3955 nucleotide sites
# Number of constant sites: 2879 (= 72.7939% of all sites)
# Number of invariant (constant or ambiguous constant) sites: 2879 (= 72.7939% of all sites)
# Number of parsimony informative sites: 507
# Number of distinct site patterns: 703
#
# SUBSTITUTION PROCESS
# --------------------
#
# Model of substitution: TIM3e+R3
#
# Rate parameter R:
#
#   A-C: 0.5146
# ...

# %%
! iqtree -m SYM+R2  -s sequences_Moskalenko_gr2_muscle.trim.fas --prefix sequences_Moskalenko_gr2_iqtree -redo
# Out:
# IQ-TREE multicore version 2.0.3 for Linux 64-bit built Dec 20 2020
# Developed by Bui Quang Minh, Nguyen Lam Tung, Olga Chernomor,
# Heiko Schmidt, Dominik Schrempf, Michael Woodhams.
#
# Host:    926634e79096 (AVX2, FMA3, 12 GB RAM)
# Command: iqtree -m SYM+R2 -s sequences_Moskalenko_gr2_muscle.trim.fas --prefix sequences_Moskalenko_gr2_iqtree -redo
# Seed:    375713 (Using SPRNG - Scalable Parallel Random Number Generator)
# Time:    Sun May 21 20:38:41 2023
# Kernel:  AVX+FMA - 1 threads (2 CPU cores detected)
#
# HINT: Use -nt option to specify number of threads because your CPU has 2 cores!
# HINT: -nt AUTO will automatically determine the best number of threads to use.
#
# Reading alignment file sequences_Moskalenko_gr2_muscle.trim.fas ... Fasta format detected
# Alignment most likely contains DNA/RNA sequences
# Alignment has 15 sequences with 3806 columns, 905 distinct patterns
# 607 parsimony-informative, 774 singleton sites, 2425 constant sites
# ...

# %%
! cat sequences_Moskalenko_gr2_iqtree.iqtree
# Out:
# IQ-TREE 2.0.3 built Dec 20 2020
#
# Input file name: sequences_Moskalenko_gr2_muscle.trim.fas
# Type of analysis: tree reconstruction
# Random seed number: 375713
#
# REFERENCES
# ----------
#
# To cite IQ-TREE please use:
#
# Bui Quang Minh, Heiko A. Schmidt, Olga Chernomor, Dominik Schrempf,
# Michael D. Woodhams, Arndt von Haeseler, and Robert Lanfear (2020)
# IQ-TREE 2: New models and efficient methods for phylogenetic inference
# in the genomic era. Mol. Biol. Evol., in press.
# https://doi.org/10.1093/molbev/msaa015
#
# SEQUENCE ALIGNMENT
# ------------------
#
# Input data: 15 sequences with 3806 nucleotide sites
# Number of constant sites: 2425 (= 63.7152% of all sites)
# Number of invariant (constant or ambiguous constant) sites: 2425 (= 63.7152% of all sites)
# Number of parsimony informative sites: 607
# Number of distinct site patterns: 905
#
# SUBSTITUTION PROCESS
# --------------------
#
# Model of substitution: SYM+R2
#
# Rate parameter R:
#
#   A-C: 0.9693
# ...

# %%
! cat sequences_Moskalenko_gr2_iqtree.iqtree
# Out:
# IQ-TREE 2.0.3 built Dec 20 2020
#
# Input file name: sequences_Moskalenko_gr2_muscle.trim.fas
# Type of analysis: tree reconstruction
# Random seed number: 375713
#
# REFERENCES
# ----------
#
# To cite IQ-TREE please use:
#
# Bui Quang Minh, Heiko A. Schmidt, Olga Chernomor, Dominik Schrempf,
# Michael D. Woodhams, Arndt von Haeseler, and Robert Lanfear (2020)
# IQ-TREE 2: New models and efficient methods for phylogenetic inference
# in the genomic era. Mol. Biol. Evol., in press.
# https://doi.org/10.1093/molbev/msaa015
#
# SEQUENCE ALIGNMENT
# ------------------
#
# Input data: 15 sequences with 3806 nucleotide sites
# Number of constant sites: 2425 (= 63.7152% of all sites)
# Number of invariant (constant or ambiguous constant) sites: 2425 (= 63.7152% of all sites)
# Number of parsimony informative sites: 607
# Number of distinct site patterns: 905
#
# SUBSTITUTION PROCESS
# --------------------
#
# Model of substitution: SYM+R2
#
# Rate parameter R:
#
#   A-C: 0.9693
# ...

# %% [markdown]
# ### Rendering ML-trees ( 3 main: all, gr1, gr2) :

# %% [markdown]
# ![Снимок экрана 2023-05-22 в 00.03.18.png](data:image/png;base64,...)![Снимок экрана 2023-05-22 в 00.04.03.png](data:image/png;base64,...)![Снимок экрана 2023-05-22 в 00.04.49.png](data:image/png;base64,...)

# %%
import requests
import pylab
from io import StringIO
from Bio import Phylo
import random
from ete3 import Tree, TreeStyle, NodeStyle
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
tree_all = Phylo.read('sequences_Moskalenko_all_iqtree.treefile', "newick")

# %%
Phylo.draw_ascii(tree_all)
# Out:
#   __________________________________ Gammarus_lacustris_1
#  |
#  |   _________________________________________________ Hyalella_azteca
#  | _|
#  || |  ____ Hyalellopsis_carinata
#  || |_|
# _||   |  _ Macropereiopus_parvus
#  ||   |_|
#  ||     |_ Eulimnogammarus_cyaneus
#  ||
#  ||__ Echiuropus_macronychus
#  |
#  | ____ Linevichella_vortex
#  ||
#   |____ Gammarus_balcanicus

# %%
Phylo.draw(tree_all, do_show=False) #

# %%
tree_gr1 = Phylo.read('sequences_Moskalenko_gr1_iqtree.treefile', "newick")

# %%
Phylo.draw_ascii(tree_gr1)
# Out:
#   _______________________________________________ Hyalella_azteca
#  |
#  , Gammarus_balcanicus
#  |
#  |, Linevichella_vortex
#  ,|
#  || Micruropus_glaber
#  |
#  |, Asprogammarus
#  ||
#  || Crypturopus_inflatus
#  |
#  | Gammarus_lacustris_1
# _|
#  , Macropereiopus_parvus
#  |
#  | Eulimnogammarus_etingovae
#  |
#  | Eucarinogammarus_wagii
#  |
#  , Eulimnogammarus_cyaneus
#  |
#  , Eulimnogammarus_tchernykhi
#  |
#  | Eulimnogammarus_cruentus
#  |
#  , Echiuropus_macronychus
#  |
#  | Hyalellopsis_carinata
#  |
#  | Pachyschesis_branchialis

# %%
Phylo.draw(tree_gr1, do_show=False) #

# %%
tree_gr2 = Phylo.read('sequences_Moskalenko_gr2_iqtree.treefile', "newick")

# %%
Phylo.draw_ascii(tree_gr2)
# Out:
#   ________ Gammarus_lacustris_1
#  |
#  |   ________________________________________________ Hyalella_azteca
#  | ,|
#  | ||_ Gammarus_montanus
#  | |
#  | |         ____ Hyalellopsis_carinata
#  | |       ,|
#  | |      _||_ Macropereiopus_parvus
#  | |     | |
#  | |   __| |_ Eulimnogammarus_cyaneus
#  | |  |  |
#  |_| ,|  |_ Echiuropus_macronychus
#  | | ||
# _| | ||____ Linevichella_vortex
#  | | |
#  | | |  _________ Gammarus_roeselii
#  | | |,|
#  | | ||| ___ Gammarus_pulex
#  | | ||||
#  | | || |___ Gammarus_fossarum
#  | |_||
#  |   || _____ Gammarus_nipponensis
#  |   |||
#  |   | |__ Gammarus_nekkensis
#  |   |
#  |   |___ Gammarus_balcanicus
#  |
#  | Gammarus_lacustris_2

# %%
Phylo.draw(tree_gr2, do_show=False) #
